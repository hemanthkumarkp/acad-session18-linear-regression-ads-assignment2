# %%
# imports
import pandas as pd
import matplotlib.pyplot as plt

# this allows plots to appear directly in the notebook
# %matplotlib inline

# %%
# read data into a DataFrame
data = pd.read_csv('http://www-bcf.usc.edu/~gareth/ISL/Advertising.csv', index_col=0)
data.head()
# Out:
#       TV  radio  newspaper  sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
# print the shape of the DataFrame
data.shape
#data.columns
data.columns
# Out:
# Index(['TV', 'radio', 'newspaper', 'sales'], dtype='object')

# %%
# visualize the relationship between the features and the response using scatterplots
fig, axs = plt.subplots(1, 3, sharey=True)
data.plot(kind='scatter', x='TV', y='sales', ax=axs[0], figsize=(16, 8))
data.plot(kind='scatter', x='radio', y='sales', ax=axs[1])
data.plot(kind='scatter', x='newspaper', y='sales', ax=axs[2])

# %%
# create X and y for TV
feature_cols = ['TV']
X1 = data[feature_cols]
y = data.sales

# follow the usual sklearn pattern: import, instantiate, fit
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X1, y)

# print intercept and coefficients
print(lm.intercept_)
print(lm.coef_)
Y1 = (lm.predict(X1))
# Out:
# 7.03259354913
# [ 0.04753664]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-3bcc9fd2b2ad> in <module>()
#      13 print(lm.coef_)
#      14 Y1 = (lm.predict(X1))
# ---> 15 print(lm.rsquared)
#
# AttributeError: 'LinearRegression' object has no attribute 'rsquared'

# %%
# create X and y for Radio
feature_cols = ['radio']
X2 = data[feature_cols]
y = data.sales

# follow the usual sklearn pattern: import, instantiate, fit
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X2, y)

# print intercept and coefficients
print(lm.intercept_)
print(lm.coef_)
Y2 = (lm.predict(X2))
# Out:
# 9.31163809516
# [ 0.20249578]

# %%
# create X and y for Newspaper
feature_cols = ['newspaper']
X3 = data[feature_cols]
y = data.sales

# follow the usual sklearn pattern: import, instantiate, fit
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X, y)

# print intercept and coefficients
print(lm.intercept_)
print(lm.coef_)
Y3 = (lm.predict(X3))
# Out:
# 12.3514070693
# [ 0.0546931]

# %%
# first, plot the observed data
data.plot(kind='scatter', x='TV', y='sales')

# then, plot the least squares line
plt.plot(X1, Y1, c='red', linewidth=2)

# %%
# first, plot the observed data
data.plot(kind='scatter', x='radio', y='sales')
plt.plot(X2, Y2, c='green', linewidth=2)

# %%
data.plot(kind='scatter', x='newspaper', y='sales')
plt.plot(X3, Y3, c='yellow', linewidth=2)

# %%
#R Squared Values for TV Radio and Newspaper
# Out:
# 0.61187505085007099

# %%
import statsmodels.formula.api as smf
lm = smf.ols(formula='sales ~ TV', data=data).fit()
lm.conf_int()
lm.rsquared
# Out:
# 0.61187505085007099

# %%
lm = smf.ols(formula='sales ~ radio', data=data).fit()
lm.conf_int()
lm.rsquared
# Out:
# 0.33203245544529525

# %%
lm = smf.ols(formula='sales ~ newspaper', data=data).fit()
lm.conf_int()
lm.rsquared
# Out:
# 0.052120445444305163
